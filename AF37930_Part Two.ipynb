# %% [markdown]
# # 7PAVREPR ASMHI Research Project
# ## Research Project Code
# ## AF37930

# %% [markdown]
# # Task 2
# ## Understanbd the data

# %% [markdown]
# ### 2.1 Import Packages need for this task
# a number of different packages are used：
#
# Pandas and NumPy were used for efficient data manipulation;
#
# Matplotlib and Seaborn  for creating figures and data visualizations;
#
# Scikit-learn’s packages like TfidfVectorizer, LogisticRegression to support Traditional machine learning methods and evaluation metrics for the performance assessment;
#
# NLTK toolkit for tokenization, stopword removal, and lemmatization
#
# Other Python standard libraries like re and string for text preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2 Loading the Filtered Dataset (data_SBDH)

# %% [markdown]
# ##### Have a look of the full discharge summary text part we filtered

# %%
data_SBDH = pd.read_csv('Dataset_Filtered.csv')
data_SBDH.head()
# Out:
#    row_id  sdoh_community_present  sdoh_community_absent  sdoh_education  \
# 0       5                       0                      0               0
# 1      42                       0                      0               0
# 2     136                       1                      0               0
# 3     442                       1                      1               0
# 4     328                       1                      0               0
#
#    sdoh_economics  sdoh_environment  behavior_alcohol  behavior_tobacco  \
# 0               0                 0                 0                 1
# 1               0                 0                 0                 2
# 2               2                 1                 3                 4
# 3               0                 1                 3                 1
# 4               2                 1                 3                 3
#
#    behavior_drug                                               TEXT  \
# 0              0  Admission Date:  [**2190-5-16**]     Discharge...
# 1              0  Admission Date:  [**2174-8-6**]              D...
# 2              0  Admission Date:  [**2139-2-4**]              D...
# 3              2  Admission Date:  [**2193-1-8**]              D...
# 4              3  Admission Date:  [**2198-4-22**]              ...
#
#                                       social_history
# 0                         She smokes a pack per day.
# 1  Social history is significant for the absence ...
# 2  Retired schoolteacher, now substitutes. Lives ...
# 3  - Tobacco: smokes 1-1.5ppd x 30yrs\n- Alcohol:...
# 4  Married with three children, born in [**2184**...

# %%
# Get the number of rows (records) in the MIMIC-SBDH dataset we use
len(data_SBDH)
# Out:
# 7025

# %% [markdown]
# The result shows that there are 7,025 records of the "social history" section in the MIMIC-SBDH dataset we selected.

# %% [markdown]
# ### 2.3 Descriptive Statistics 1
# ### Distribution of Number of SDMHs Categories Mentioned per discharge summary

# %%
# For each record (row), count how many SBDH categories are mentioned (Community categories combined)
def count_sbdh(row):
    count = 0
    # If Community Present or Community Absent is mentioned (value == 1),
    # add one to the count of SDMH categories mentioned in this record
    if row['sdoh_community_present'] == 1 or row['sdoh_community_absent'] == 1:
        count += 1
    # If Education is mentioned (value == 1), add one
    if row['sdoh_education'] == 1:
        count += 1
    # # If Economics or Environment is mentioned (value 1 or 2), add one for each
    if row['sdoh_economics'] in [1, 2]:
        count += 1
    if row['sdoh_environment'] in [1, 2]:
        count += 1
     # If any Behavior category (Alcohol, Tobacco, Drug) is mentioned (value in 1-4), add one for each
    if row['behavior_alcohol'] in [1, 2, 3, 4]:
        count += 1
    if row['behavior_tobacco'] in [1, 2, 3, 4]:
        count += 1
    if row['behavior_drug'] in [1, 2, 3, 4]:
        count += 1
    return count

sbdh_counts = data_SBDH.apply(count_sbdh, axis=1)
distribution = sbdh_counts.value_counts()

# Plot
fig, axes = plt.subplots(figsize=(9, 6))
bars = plt.bar(distribution.index, distribution.values, color='indigo')

axes.bar_label(bars)

plt.xlabel('Number of SBDHs Categories Mentioned')
plt.ylabel('Number of Discharge Summaries')
plt.title('Distribution of Number of SBDHs Categories Mentioned Per Record(Community Combined)')
plt.savefig('descriptive1.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# The result shows that out of the 7,025 annotated discharge summaries, 6775 ones (over 95%) discussed at least one category of SBDH.

# %% [markdown]
# ### 2.4 Descriptive Statistics 2
# ### Frequency Diswtruibution of SDMH Discussions in Social History Sections()

# %%
# Count how many times each category is actually discussed 
# (not None and not labeled as 'Unsure')
counts = {}

# Community-Present: 1 = discussed
# (discussed social support)
counts['Community-Present'] = (data_SBDH['sdoh_community_present'] == 1).sum()

# Community-Absent: 1 = discussed
# (discussed loss of social support)
counts['Community-Absent'] = (data_SBDH['sdoh_community_absent'] == 1).sum()

# Education: 1 = discussed
# (discussed the patient’s education such as schooling, college or degree)
counts['Education'] = (data_SBDH['sdoh_education'] == 1).sum()

# Economics: 1 or 2 discussed
# (1 discussed patient was currently employed, 2 discussed patient was unemployed (including retirement)
counts['Economics'] = data_SBDH['sdoh_economics'].isin([1, 2]).sum()

# Environment: 1 or 2 discussed
# (1 discussed any indication of housing, 2 discussed homeless)
counts['Environment'] = data_SBDH['sdoh_environment'].isin([1, 2]).sum()

# Alcohol Use: 2-4 discussed
# (2 discussed present use, 3 discussed past use, 4 discussed never use)
counts['Alcohol Use'] = data_SBDH['behavior_alcohol'].isin([2, 3, 4]).sum()

# Tobacco Use: 2-4 discussed
counts['Tobacco Use'] = data_SBDH['behavior_tobacco'].isin([2, 3, 4]).sum()

# Drug Use: 2-4 discussed
counts['Drug Use'] = data_SBDH['behavior_drug'].isin([2, 3, 4]).sum()

# 1. Print
print("The frequency of mentions for each SDMH category：")
for a, b in counts.items():
    print(f"{a}: {b}")

# 2.Plot
fig, axes = plt.subplots(figsize=(9, 6))
names = ["Community\nPresent", "Community\nAbsent", "Education", "Economics",
         "Environment", "Alcohol Use", "Tobacco Use", "Drug Use"]
bars = axes.bar(names, list(counts.values()), color='thistle')
axes.bar_label(bars)
axes.set_ylabel('Number of Discharge Summaries')
axes.set_title('Frequency of SBDH Discussion in Discharge Summaries')
plt.tight_layout()
plt.savefig('descriptive2.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# The frequency of mentions for each SDMH category：
# Community-Present: 4463
# Community-Absent: 784
# Education: 210
# Economics: 2730
# Environment: 4420
# Alcohol Use: 3291
# Tobacco Use: 4728
# Drug Use: 2501

# %% [markdown]
# The result shows that Community Present(4463), Tobacco Use(4728), and Environment(4420) are the topics discussed most frequently in the discharge summaries. In contrast, Community Absent(784) and Education(210) were discussed the least often.

# %% [markdown]
# ### 2.5 Descriptive Statistics 3
# ### Distribution of Category States Across 8 SDMH Domains

# %%
columns = {
    'sdoh_community_present': {0: 'False', 1: 'True'},
    'sdoh_community_absent': {0: 'False', 1: 'True'},
    'sdoh_education': {0: 'False', 1: 'True'},
    'sdoh_economics': {0: 'None', 1: 'True', 2: 'False'},
    'sdoh_environment': {0: 'None', 1: 'True', 2: 'False'},
    'behavior_alcohol': {0: 'None', 1: 'Present', 2: 'Past', 3: 'Never', 4: 'Unsure'},
    'behavior_tobacco': {0: 'None', 1: 'Present', 2: 'Past', 3: 'Never', 4: 'Unsure'},
    'behavior_drug': {0: 'None', 1: 'Present', 2: 'Past', 3: 'Never', 4: 'Unsure'}
}

# Tables
for col, mapping in columns.items():
    if col in data_SBDH.columns:
        counts = data_SBDH[col].value_counts()
        counts.index = counts.index.map(mapping)
        print(f"Category counts for {col}:")
        print(counts.to_string())
        print('-' * 66)
# Out:
# Category counts for sdoh_community_present:
# sdoh_community_present
# True     4463
# False    2562
# ------------------------------------------------------------------
# Category counts for sdoh_community_absent:
# sdoh_community_absent
# False    6241
# True      784
# ------------------------------------------------------------------
# Category counts for sdoh_education:
# sdoh_education
# False    6815
# True      210
# ------------------------------------------------------------------
# Category counts for sdoh_economics:
# sdoh_economics
# None     4295
# False    1742
# True      988
# ------------------------------------------------------------------
# Category counts for sdoh_environment:
# sdoh_environment
# True     4357
# None     2605
# False      63
# ------------------------------------------------------------------
# Category counts for behavior_alcohol:
# behavior_alcohol
# Never      2444
# Present    2077
# None       1657
# Past        515
# Unsure      332
# ------------------------------------------------------------------
# Category counts for behavior_tobacco:
# behavior_tobacco
# Never      2252
# Past       2121
# None       1291
# Present    1006
# Unsure      355
# ------------------------------------------------------------------
# Category counts for behavior_drug:
# behavior_drug
# None       4317
# Never      2136
# Past        221
# Present     207
# Unsure      144
# ------------------------------------------------------------------

# %%
class_colors={0: '#4B0082', 1: 'thistle', 2: 'mediumpurple', 3: 'plum', 4: '#8A2BE2'}

# n_bars_per_label = [len(classes) for _, classes in label_info.values()]
# total_bars = sum(n_bars_per_label)
# total bars numbers = 2 + 2 + 2 + 3 + 3 + 5 + 5 + 5  = 27

group_gap = 0.2
width_available = 8 - group_gap * 7

label_widths = [2 / 27 * width_available, 2 / 27 * width_available, 2 / 27 * width_available, 3 / 27 * width_available,
                3 / 27 * width_available, 5 / 27 * width_available, 5 / 27 * width_available, 5 / 27 * width_available]
label_starts = []
start = 0
for width in label_widths:
    label_starts.append(start)
    start += width + group_gap

# Plot
fig, ax = plt.subplots(figsize=(18, 9))
current_x = 0

for idx, (col_name, mapping) in enumerate(columns.items()):
    classes = list(mapping.keys())
    labels = list(mapping.values())
    n_classes = len(classes)
    label_width = label_widths[idx]

    bar_width = label_width / n_classes * 0.9

    for j, cls_val in enumerate(classes):
        count = (data_SBDH[col_name] == cls_val).sum()
        x_pos = current_x + j * (label_width / n_classes) + bar_width / 2
        color = class_colors.get(cls_val) 
        ax.bar(x_pos, count, width=bar_width, color=color)
        ax.text(x_pos, count, str(count), ha='center', va='bottom', fontsize=11)
        ax.text(x_pos, -20, labels[j], ha='center', va='top', fontsize=10)
    current_x += label_width + group_gap

xticks = [start + w / 2 for start, w in zip(label_starts, label_widths)]
ax.set_xticks(xticks)

labelnames = ['Community\nPresent', 'Community\nAbsent', 'Education', 'Economics',
                   'Environment', 'Alcohol Use', 'Tobacco Use', 'Drug Use']
ax.set_xticklabels(labelnames, fontsize=14)

ax.set_ylabel('Number of Samples', fontsize=14)
ax.set_title('Distribution of Label Categories Values Within 8 Kinds of SBDH', fontsize=20, fontweight='bold')

ax.set_ylim(-300, 8000)
plt.tight_layout()
plt.savefig('descriptive3.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Distribution of Number of 8 kinds of SBDHs:
#
# The result shows that overall the data is quite imbalanced across most variables.For example, in sdoh_education only 210 entries are marked True while 6815 are False. In behavior_drug most entries are None or Never, and only 207 are marked Present.

# %%
print(data_SBDH['social_history'].isna().sum())
# Out:
# 0

# %% [markdown]
# # Task 3
# ## Traditional Model

# %% [markdown]
# Baseline Systems (conventional machine learning techniques)

# %% [markdown]
# ### 3.1 ML preparation

# %% [markdown]
# #### 3.1.1 Import Packages

# %%
# %pip install scikit-multilearn
# Out:
# Collecting scikit-multilearn
#   Downloading scikit_multilearn-0.2.0-py3-none-any.whl.metadata (6.0 kB)
# Downloading scikit_multilearn-0.2.0-py3-none-any.whl (89 kB)
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from scikit-learn) (2.0.2)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---------------------------------------- 11.2/11.2 MB 63.3 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    -------------------- ------------------- 24.1/46.2 MB 117.5 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 113.0 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 91.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.1 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0

# %%
# %pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.9-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from iterative-stratification) (2.0.2)
# Requirement already satisfied: scipy in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from iterative-stratification) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from iterative-stratification) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from scikit-learn->iterative-stratification) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from scikit-learn->iterative-stratification) (3.6.0)
# Downloading iterative_stratification-0.1.9-py3-none-any.whl (8.5 kB)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import these packages requied to use
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report


from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# For multilavel stratified split
from sklearn.preprocessing import OneHotEncoder
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit

# %% [markdown]
# #### 3.1.2 Split the dataset into train, val and testing dataset

# %% [markdown]
# https://github.com/trent-b/iterative-stratification
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html

# %%
multi_cls_cols = ['sdoh_economics','sdoh_environment','behavior_alcohol', 'behavior_tobacco', 'behavior_drug']
binary_cls_cols = ['sdoh_community_present', 'sdoh_community_absent', 'sdoh_education']

encoder = OneHotEncoder(sparse_output=False)
y_multiclass_onehot = encoder.fit_transform(data_SBDH[multi_cls_cols])
y_binaryclass = data_SBDH[binary_cls_cols].values
y_full = np.hstack([y_multiclass_onehot, y_binaryclass])

# First Split: 70% (Train)，remain 30% (validation and test)
split1 = MultilabelStratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
for train_index, val_test_index in split1.split(data_SBDH, y_full):

    # Second Split：In the remaining 30% validation and test set, split 15% validation, 15% test
    split2 = MultilabelStratifiedShuffleSplit(n_splits=1, test_size=0.5, random_state=42)
    for subval_index, subtest_index in split2.split(data_SBDH.iloc[val_test_index], y_full[val_test_index]):
        val_index = val_test_index[subval_index]
        test_index = val_test_index[subtest_index]

data_train = data_SBDH.iloc[train_index].reset_index(drop=True)
data_val = data_SBDH.iloc[val_index].reset_index(drop=True)
data_test = data_SBDH.iloc[test_index].reset_index(drop=True)

print(f"Train : {len(data_train)}")
print(f"Val : {len(data_val)}")
print(f"Test : {len(data_test)}")
# Out:
# Train : 4917
# Val : 1055
# Test : 1053

# %% [markdown]
# #### 3.1.3 Comparison of Label Proportions Across Dataset Splits (Training, Validation, and Test Sets)

# %%
full_cols = binary_cls_cols + multi_cls_cols

print("Training set distribution:")
for col in full_cols:
    print(f"{col} distribution:")
    print(data_train[col].value_counts(normalize=True).to_string())
print("-" * 30)

print("Validation set distribution:")
for col in full_cols:
    print(f"{col} distribution:")
    print(data_val[col].value_counts(normalize=True).to_string())
print("-" * 30)

print("Test set distribution:")
for col in full_cols:
    print(f"{col} distribution:")
    print(data_test[col].value_counts(normalize=True).to_string())
print("-" * 30)
# Out:
# Training set distribution:
# sdoh_community_present distribution:
# sdoh_community_present
# 1    0.635347
# 0    0.364653
# sdoh_community_absent distribution:
# sdoh_community_absent
# 0    0.888347
# 1    0.111653
# sdoh_education distribution:
# sdoh_education
# 0    0.970104
# 1    0.029896
# sdoh_economics distribution:
# sdoh_economics
# 0    0.611348
# 2    0.247915
# 1    0.140736
# sdoh_environment distribution:
# sdoh_environment
# 1    0.620297
# 0    0.370755
# 2    0.008949
# behavior_alcohol distribution:
# behavior_alcohol
# 3    0.347976
# 1    0.295709
# 0    0.235916
# 2    0.073215
# 4    0.047183
# behavior_tobacco distribution:
# behavior_tobacco
# 3    0.320521
# 2    0.302013
# 0    0.183852
# 1    0.143177
# 4    0.050437
# behavior_drug distribution:
# behavior_drug
# 0    0.614399
# 3    0.304047
# 2    0.031523
# 1    0.029490
# 4    0.020541
# ------------------------------
# Validation set distribution:
# sdoh_community_present distribution:
# sdoh_community_present
# 1    0.634123
# 0    0.365877
# sdoh_community_absent distribution:
# sdoh_community_absent
# 0    0.8891
# 1    0.1109
# sdoh_education distribution:
# sdoh_education
# 0    0.969668
# 1    0.030332
# sdoh_economics distribution:
# sdoh_economics
# 0    0.612322
# 2    0.247393
# 1    0.140284
# sdoh_environment distribution:
# sdoh_environment
# 1    0.619905
# 0    0.370616
# 2    0.009479
# behavior_alcohol distribution:
# behavior_alcohol
# 3    0.346919
# 1    0.295735
# 0    0.236019
# 2    0.073934
# 4    0.047393
# behavior_tobacco distribution:
# behavior_tobacco
# 3    0.320379
# 2    0.301422
# 0    0.183886
# 1    0.143128
# 4    0.051185
# behavior_drug distribution:
# behavior_drug
# 0    0.616114
# 3    0.303318
# 2    0.031280
# 1    0.029384
# 4    0.019905
# ------------------------------
# Test set distribution:
# sdoh_community_present distribution:
# sdoh_community_present
# 1    0.636277
# 0    0.363723
# sdoh_community_absent distribution:
# sdoh_community_absent
# 0    0.887939
# 1    0.112061
# sdoh_education distribution:
# sdoh_education
# 0    0.97056
# 1    0.02944
# sdoh_economics distribution:
# sdoh_economics
# 0    0.610636
# 2    0.248813
# 1    0.140551
# sdoh_environment distribution:
# sdoh_environment
# 1    0.620133
# 0    0.371320
# 2    0.008547
# behavior_alcohol distribution:
# behavior_alcohol
# 3    0.348528
# 1    0.295347
# 0    0.235518
# 2    0.073124
# 4    0.047483
# behavior_tobacco distribution:
# behavior_tobacco
# 3    0.320988
# 2    0.301994
# 0    0.183286
# 1    0.143400
# 4    0.050332
# behavior_drug distribution:
# behavior_drug
# 0    0.613485
# 3    0.304843
# 2    0.031339
# 1    0.029440
# 4    0.020893
# ------------------------------

# %% [markdown]
# The result shows that the label distributions look relatively similar across the training, validation, and test sets, which means the stratified split worked well.

# %% [markdown]
# ##### Save threedatasets to CSV files.

# %%
data_train.to_csv('data_train.csv', index=False)
data_val.to_csv('data_val.csv', index=False)
data_test.to_csv('data_test.csv', index=False)

# %%
data_train.head()
# Out:
#    row_id  sdoh_community_present  sdoh_community_absent  sdoh_education  \
# 0      42                       0                      0               0
# 1     328                       1                      0               0
# 2     410                       0                      0               0
# 3     416                       0                      0               0
# 4     671                       1                      0               0
#
#    sdoh_economics  sdoh_environment  behavior_alcohol  behavior_tobacco  \
# 0               0                 0                 0                 2
# 1               2                 1                 3                 3
# 2               2                 1                 3                 2
# 3               2                 1                 0                 0
# 4               2                 1                 2                 2
#
#    behavior_drug                                               TEXT  \
# 0              0  Admission Date:  [**2174-8-6**]              D...
# 1              3  Admission Date:  [**2198-4-22**]              ...
# 2              3  Admission Date:  [**2146-7-15**]              ...
# 3              3  Admission Date:  [**2123-8-15**]              ...
# 4              3  Admission Date:  [**2158-12-12**]             ...
#
#                                       social_history
# 0  Social history is significant for the absence ...
# 1  Married with three children, born in [**2184**...
# 2  The patient has a sixty-pack-year history of t...
# 3  Formerly worked in insurance, not working curr...
# 4  Lives with his wife, retired plumbing/heating\...

# %% [markdown]
# ### 3.2 Preprocessing Function

# %% [markdown]
# I defined a preprocessing function to clean and normalize raw text data. This progress includes the steps:
#
# Converts text to lowercase; Remove numbers; Remove punctations; Tokenizes the text into individual words Removes common English stopwords like 'the', 'of'; Lemmatize these words.

# %%
data_train = pd.read_csv('data_train.csv')
data_val = pd.read_csv('data_val.csv')
data_test = pd.read_csv('data_test.csv')

# %%
# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from nltk) (1.5.1)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.7.34-cp39-cp39-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 20.1 MB/s eta 0:00:00
# Downloading regex-2025.7.34-cp39-cp39-win_amd64.whl (276 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, click, nltk
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [click]
#    -------------------- ------------------- 2/4 [click]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ---------------------------------------- 4/4 [nltk]
#
# Successfully installed click-8.1.8 nltk-3.9.1 regex-2025.7.34 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\k24034365\.conda\envs\tf\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'C:\Users\k24034365\.conda\envs\tf\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# New
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

def get_clean_text(input_data):
    stopwords_modified = set(stopwords.words('english')) - {"no", "not", "nor", "without", "never"}

    input_data = input_data.lower()
    input_data = re.sub(r'\[\*\*.*?\*\*\]', '', input_data)
    input_data = re.sub(r'\d+', '', input_data)

    tokens = word_tokenize(input_data)
    tokens = [token for token in tokens if token not in string.punctuation] 
    lemmas = [WordNetLemmatizer().lemmatize(token) for token in tokens if token not in stopwords_modified]

    return ' '.join(lemmas)

# Apply preprocessing
data_train['clean_social_history'] = data_train['social_history'].apply(get_clean_text)
data_val['clean_social_history'] = data_val['social_history'].apply(get_clean_text)
data_test['clean_social_history'] = data_test['social_history'].apply(get_clean_text)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\k24034365\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\k24034365\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\k24034365\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Take a look at the text after the preprocessing

# %%
example = data_train['social_history'].iloc[99]
print(get_clean_text(example))
# Out:
# life married kid army lt. general quit tob year ago no etoh

# %%
data_train[['social_history', 'clean_social_history']].head()
# Out:
#                                       social_history  \
# 0  Social history is significant for the absence ...
# 1  Married with three children, born in [**2184**...
# 2  The patient has a sixty-pack-year history of t...
# 3  Formerly worked in insurance, not working curr...
# 4  Lives with his wife, retired plumbing/heating\...
#
#                                 clean_social_history
# 0  social history significant absence current tob...
# 1  married three child born life went worked acco...
# 2  patient sixty-pack-year history tobacco quit l...
# 3  formerly worked insurance not working currentl...
# 4  life wife retired plumbing/heating tob smoked ...

# %% [markdown]
# ### 3.3 Vectorization (TF-IDF)

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Use CountVectorizer to count word frequencies without limiting the number of features
vocab_size = len(CountVectorizer().fit(data_train['clean_social_history']).get_feature_names_out())
print('Total vocabulary size (number of features):')
print(vocab_size)
# Out:
# Total vocabulary size (number of features):
# 4793

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X_train_TFIDF = TfidfVectorizer().fit_transform(data_train['clean_social_history'])
X_dev_TFIDF = TfidfVectorizer().fit(data_train['clean_social_history']).transform(data_val['clean_social_history'])
X_test_TFIDF = TfidfVectorizer().fit(data_train['clean_social_history']).transform(data_test['clean_social_history'])

y_train = data_train[full_cols].values
y_dev = data_val[full_cols].values
y_test = data_test[full_cols].values

# %%
print(X_train_TFIDF.shape)
print(y_train.shape)
print(y_train[:5])
# Out:
# (4917, 4793)
# (4917, 8)
# [[0 0 0 0 0 0 2 0]
#  [1 0 0 2 1 3 3 3]
#  [0 0 0 2 1 3 2 3]
#  [0 0 0 2 1 0 0 3]
#  [1 0 0 2 1 2 2 3]]

# %% [markdown]
# ### 3.4 Random Forest

# %% [markdown]
# #### 3.4.1 Buid Model (5 folds CV to tune the hyperparameters)

# %% [markdown]
# add the prefix estimator__.
#
# https://scikit-learn.org/stable/modules/grid_search.html#grid-search
#
# https://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html
#
# For the multi-output classification task, I referred to the above documentation. During hyperparameter tuning via grid search, the estimator_ prefix was used to tune the composite estimators.

# %% [markdown]
# Parameters were selected based on the article by Priyansh Soni. https://www.blog.trainindata.com/random-forest-with-grid-search/. Considering the computational time in the notebook environment, I selected a simplified set of key Random Forest hyperparameters and did not tune max_features.

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import make_scorer

# Calculates the mean macro F1-score across 8 labels to as the performance metric for grid search hyperparameter tuning
def mean_macro_f1_score(y_true, y_pred):
    f1s = []
    # Use for loop to calculate macro f1 over 8 label names and their indices
    for i, label in enumerate(full_cols):
        f1 = f1_score(y_true[:, i], y_pred[:, i], average='macro')
        f1s.append(f1)
    return np.mean(f1s)

perlabel_rf = RandomForestClassifier(random_state=42)
multi_rf = MultiOutputClassifier(perlabel_rf)

# Add the prefix estimator__ to use the multi-output classifier
param_grid_rf = {
    'estimator__n_estimators': [100, 200],
    'estimator__max_depth': [10, 20, None],
    'estimator__min_samples_split': [2, 5],
    'estimator__max_features': ['sqrt', 'log2', None],
    'estimator__min_samples_leaf': [1, 2]
}

grid_search_rf = GridSearchCV(
    estimator=multi_rf,
    param_grid=param_grid_rf,
    cv=5,
    scoring=make_scorer(mean_macro_f1_score),
    verbose=1,
    n_jobs=-1
)

grid_search_rf.fit(X_train_TFIDF, y_train)

print("Best Parameters:")
print(grid_search_rf.best_params_)

print("Best CV Macro F1 Score: " + str(round(grid_search_rf.best_score_, 4)))
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best Parameters:
# {'estimator__max_depth': 20, 'estimator__max_features': None, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__n_estimators': 100}
# Best CV Macro F1 Score: 0.8323

# %% [markdown]
# #### 3.4.2 Test RandomForest Performance

# %%
# Make predictions
y_test_pred = grid_search_rf.best_estimator_.predict(X_test_TFIDF)

precision_macro = []
recall_macro = []
f1_macro = []

precision_weighted = []
recall_weighted = []
f1_weighted = []

for i, label in enumerate(full_cols):
    print(f"\nLabel: {label}")
    print(classification_report(y_test[:, i], y_test_pred[:, i], digits=4))

    # macro
    prec = precision_score(y_test[:, i], y_test_pred[:, i], average='macro')
    rec = recall_score(y_test[:, i], y_test_pred[:, i], average='macro')
    f1 = f1_score(y_test[:, i], y_test_pred[:, i], average='macro')

    precision_macro.append(prec)
    recall_macro.append(rec)
    f1_macro.append(f1)

    # weighted
    prec_w = precision_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    rec_w = recall_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    f1_w = f1_score(y_test[:, i], y_test_pred[:, i], average='weighted')

    precision_weighted.append(prec_w)
    recall_weighted.append(rec_w)
    f1_weighted.append(f1_w)

# The macro precision, recall, and F1-score were computed by averaging the per-label macro scores in the above classification report
print("-" * 30)
print("\nMacro-Average Results:")
print("Macro Precision: " + str(round(sum(precision_macro) / len(precision_macro), 4)))
print("Macro Recall: " + str(round(sum(recall_macro) / len(recall_macro), 4)))
print("Macro F1-Score: " + str(round(sum(f1_macro) / len(f1_macro), 4)))


# The weighted scores were computed by averaging the per-label weighted scores in the above classification report
print("\nWeighted-Average Results:")
print(f"Weighted Precision: {sum(precision_weighted) / len(precision_weighted):.4f}")
print(f"Weighted Recall: {sum(recall_weighted) / len(recall_weighted):.4f}")
print(f"Weighted F1-Score: {sum(f1_weighted) / len(f1_weighted):.4f}")
# Out:
# Label: sdoh_community_present
#               precision    recall  f1-score   support
#
#            0     0.9271    0.9295    0.9283       383
#            1     0.9596    0.9582    0.9589       670
#
#     accuracy                         0.9478      1053
#    macro avg     0.9434    0.9439    0.9436      1053
# weighted avg     0.9478    0.9478    0.9478      1053
#
#
# Label: sdoh_community_absent
#               precision    recall  f1-score   support
#
#            0     0.9658    0.9979    0.9816       935
#            1     0.9770    0.7203    0.8293       118
#
#     accuracy                         0.9668      1053
#    macro avg     0.9714    0.8591    0.9054      1053
# weighted avg     0.9671    0.9668    0.9645      1053
#
#
# Label: sdoh_education
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9912    0.9951      1022
#            1     0.7692    0.9677    0.8571        31
#
#     accuracy                         0.9905      1053
#    macro avg     0.8841    0.9795    0.9261      1053
# weighted avg     0.9922    0.9905    0.9910      1053
#
#
# Label: sdoh_economics
#               precision    recall  f1-score   support
#
#            0     0.9445    0.9798    0.9618       643
#            1     0.8333    0.7095    0.7664       148
#            2     0.9000    0.8931    0.8966       262
#
#     accuracy                         0.9202      1053
#    macro avg     0.8926    0.8608    0.8749      1053
# weighted avg     0.9178    0.9202    0.9181      1053
#
#
# Label: sdoh_environment
#               precision    recall  f1-score   support
#
#            0     0.9643    0.9668    0.9655       391
#            1     0.9756    0.9786    0.9771       653
#            2     1.0000    0.6667    0.8000         9
#
#     accuracy                         0.9715      1053
#    macro avg     0.9800    0.8707    0.9142      1053
# weighted avg     0.9716    0.9715    0.9713      1053
#
#
# Label: behavior_alcohol
#               precision    recall  f1-score   support
#
#            0     0.9675    0.9597    0.9636       248
#            1     0.8255    0.8521    0.8386       311
#            2     0.7500    0.2727    0.4000        77
#            3     0.8053    0.9128    0.8557       367
#            4     0.6429    0.5400    0.5870        50
#
#     accuracy                         0.8414      1053
#    macro avg     0.7982    0.7075    0.7290      1053
# weighted avg     0.8377    0.8414    0.8300      1053
#
#
# Label: behavior_tobacco
#               precision    recall  f1-score   support
#
#            0     0.9679    0.9378    0.9526       193
#            1     0.7958    0.7483    0.7713       151
#            2     0.9035    0.8836    0.8935       318
#            3     0.8661    0.9379    0.9006       338
#            4     0.7872    0.6981    0.7400        53
#
#     accuracy                         0.8822      1053
#    macro avg     0.8641    0.8412    0.8516      1053
# weighted avg     0.8820    0.8822    0.8814      1053
#
#
# Label: behavior_drug
#               precision    recall  f1-score   support
#
#            0     0.9827    0.9675    0.9750       646
#            1     0.6071    0.5484    0.5763        31
#            2     0.6818    0.4545    0.5455        33
#            3     0.8886    0.9688    0.9270       321
#            4     0.6471    0.5000    0.5641        22
#
#     accuracy                         0.9297      1053
#    macro avg     0.7615    0.6879    0.7176      1053
# weighted avg     0.9265    0.9297    0.9266      1053
#
# ------------------------------
#
# Macro-Average Results:
# Macro Precision: 0.8869
# Macro Recall: 0.8438
# Macro F1-Score: 0.8578
#
# Weighted-Average Results:
# Weighted Precision: 0.9303
# Weighted Recall: 0.9313
# Weighted F1-Score: 0.9288

# %% [markdown]
# ### 3.5 XGBoost

# %% [markdown]
# #### 3.5.1 Buid XGBoost Model (5 folds CV to tune the hyperparameters)

# %%
# %pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from xgboost) (2.0.2)
# Requirement already satisfied: scipy in c:\users\k24034365\.conda\envs\tf\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 1.3/124.9 MB 7.4 MB/s eta 0:00:17
#    - -------------------------------------- 3.7/124.9 MB 9.1 MB/s eta 0:00:14
#    -- ------------------------------------- 7.1/124.9 MB 11.5 MB/s eta 0:00:11
#    --- ------------------------------------ 11.3/124.9 MB 13.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 16.0/124.9 MB 15.5 MB/s eta 0:00:08
#    ------ --------------------------------- 21.8/124.9 MB 17.4 MB/s eta 0:00:06
#    --------- ------------------------------ 28.6/124.9 MB 19.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 36.2/124.9 MB 21.7 MB/s eta 0:00:05
#    -------------- ------------------------- 44.0/124.9 MB 23.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 53.0/124.9 MB 25.4 MB/s eta 0:00:03
#    ------------------- -------------------- 62.4/124.9 MB 27.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 72.4/124.9 MB 29.0 MB/s eta 0:00:02
#    -------------------------- ------------- 83.6/124.9 MB 31.0 MB/s eta 0:00:02
#    ------------------------------ --------- 95.4/124.9 MB 32.7 MB/s eta 0:00:01
#    --------------------------------- ----- 107.7/124.9 MB 34.6 MB/s eta 0:00:01
#    ------------------------------------- - 121.4/124.9 MB 36.6 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 36.9 MB/s eta 0:00:01
#    --------------------------------------- 124.9/124.9 MB 35.0 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import make_scorer
from sklearn.metrics import make_scorer, f1_score

def mean_macro_f1_score(y_true, y_pred):
    f1s = []
    # Use for loop to calculate macro f1 over 8 label names and their indices
    for i, label in enumerate(full_cols):
        f1 = f1_score(y_true[:, i], y_pred[:, i], average='macro')
        f1s.append(f1)
    return np.mean(f1s)

perlabel_xgb = XGBClassifier(eval_metric='logloss', random_state=42)
multi_xgb = MultiOutputClassifier(perlabel_xgb)
# Add the prefix estimator__ to define the hyperparameter search space to  use the multi-output classifie
param_grid_xgb = {'estimator__n_estimators': [100, 200], 'estimator__max_depth': [3, 5, 7],
              'estimator__learning_rate': [0.01, 0.1, 0.2], 'estimator__subsample': [0.8, 1.0],
              'estimator__min_child_weight':[1, 3, 5]}

grid_search_xgb = GridSearchCV(
    estimator=multi_xgb,
    param_grid=param_grid_xgb,
    cv=5,
    # Use thesame performance score (Macro f1) in the random forest 
    scoring=make_scorer(mean_macro_f1_score),
    verbose=1,
    n_jobs=-1
)

grid_search_xgb.fit(X_train_TFIDF, y_train)

print("Best Parameters:")
print(grid_search_xgb.best_params_)
print("Best CV Macro F1 Score: " + str(round(grid_search_xgb.best_score_, 4)))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters:
# {'estimator__learning_rate': 0.2, 'estimator__max_depth': 5, 'estimator__min_child_weight': 1, 'estimator__n_estimators': 200, 'estimator__subsample': 1.0}
# Best CV Macro F1 Score: 0.8391

# %% [markdown]
# #### 3.4.2 Test XGBoost Performance

# %%
# Make predictions
y_test_pred = grid_search_xgb.best_estimator_.predict(X_test_TFIDF)

precision_macro = []
recall_macro = []
f1_macro = []

precision_weighted = []
recall_weighted = []
f1_weighted = []

for i, label in enumerate(full_cols):
    print(f"\nLabel: {label}")
    print(classification_report(y_test[:, i], y_test_pred[:, i], digits=4))

    # macro
    prec = precision_score(y_test[:, i], y_test_pred[:, i], average='macro')
    rec = recall_score(y_test[:, i], y_test_pred[:, i], average='macro')
    f1 = f1_score(y_test[:, i], y_test_pred[:, i], average='macro')

    precision_macro.append(prec)
    recall_macro.append(rec)
    f1_macro.append(f1)

    # weighted
    prec_w = precision_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    rec_w = recall_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    f1_w = f1_score(y_test[:, i], y_test_pred[:, i], average='weighted')

    precision_weighted.append(prec_w)
    recall_weighted.append(rec_w)
    f1_weighted.append(f1_w)

# The macro precision, recall, and F1-score were computed by averaging the per-label macro scores in the above classification report
print("-" * 30)
print("\nMacro-Average Results:")
print("Macro Precision: " + str(round(sum(precision_macro) / len(precision_macro), 4)))
print("Macro Recall: " + str(round(sum(recall_macro) / len(recall_macro), 4)))
print("Macro F1-Score: " + str(round(sum(f1_macro) / len(f1_macro), 4)))


# The weighted scores were computed by averaging the per-label weighted scores in the above classification report
print("\nWeighted-Average Results:")
print(f"Weighted Precision: {sum(precision_weighted) / len(precision_weighted):.4f}")
print(f"Weighted Recall: {sum(recall_weighted) / len(recall_weighted):.4f}")
print(f"Weighted F1-Score: {sum(f1_weighted) / len(f1_weighted):.4f}")
# Out:
# Label: sdoh_community_present
#               precision    recall  f1-score   support
#
#            0     0.9493    0.9295    0.9393       383
#            1     0.9602    0.9716    0.9659       670
#
#     accuracy                         0.9563      1053
#    macro avg     0.9548    0.9506    0.9526      1053
# weighted avg     0.9562    0.9563    0.9562      1053
#
#
# Label: sdoh_community_absent
#               precision    recall  f1-score   support
#
#            0     0.9666    0.9914    0.9789       935
#            1     0.9149    0.7288    0.8113       118
#
#     accuracy                         0.9620      1053
#    macro avg     0.9408    0.8601    0.8951      1053
# weighted avg     0.9608    0.9620    0.9601      1053
#
#
# Label: sdoh_education
#               precision    recall  f1-score   support
#
#            0     0.9883    0.9961    0.9922      1022
#            1     0.8261    0.6129    0.7037        31
#
#     accuracy                         0.9848      1053
#    macro avg     0.9072    0.8045    0.8480      1053
# weighted avg     0.9836    0.9848    0.9837      1053
#
#
# Label: sdoh_economics
#               precision    recall  f1-score   support
#
#            0     0.9456    0.9736    0.9594       643
#            1     0.8195    0.7365    0.7758       148
#            2     0.8953    0.8817    0.8885       262
#
#     accuracy                         0.9174      1053
#    macro avg     0.8868    0.8639    0.8745      1053
# weighted avg     0.9154    0.9174    0.9159      1053
#
#
# Label: sdoh_environment
#               precision    recall  f1-score   support
#
#            0     0.9695    0.9744    0.9719       391
#            1     0.9816    0.9816    0.9816       653
#            2     1.0000    0.7778    0.8750         9
#
#     accuracy                         0.9772      1053
#    macro avg     0.9837    0.9113    0.9429      1053
# weighted avg     0.9773    0.9772    0.9771      1053
#
#
# Label: behavior_alcohol
#               precision    recall  f1-score   support
#
#            0     0.9754    0.9597    0.9675       248
#            1     0.8558    0.8585    0.8571       311
#            2     0.7000    0.4545    0.5512        77
#            3     0.8317    0.9292    0.8777       367
#            4     0.7568    0.5600    0.6437        50
#
#     accuracy                         0.8632      1053
#    macro avg     0.8239    0.7524    0.7794      1053
# weighted avg     0.8595    0.8632    0.8578      1053
#
#
# Label: behavior_tobacco
#               precision    recall  f1-score   support
#
#            0     0.9615    0.9067    0.9333       193
#            1     0.8444    0.7550    0.7972       151
#            2     0.8944    0.9057    0.9000       318
#            3     0.8753    0.9556    0.9137       338
#            4     0.8000    0.6792    0.7347        53
#
#     accuracy                         0.8889      1053
#    macro avg     0.8751    0.8404    0.8558      1053
# weighted avg     0.8887    0.8889    0.8875      1053
#
#
# Label: behavior_drug
#               precision    recall  f1-score   support
#
#            0     0.9706    0.9706    0.9706       646
#            1     0.6087    0.4516    0.5185        31
#            2     0.6364    0.4242    0.5091        33
#            3     0.8743    0.9533    0.9121       321
#            4     0.5000    0.2727    0.3529        22
#
#     accuracy                         0.9183      1053
#    macro avg     0.7180    0.6145    0.6526      1053
# weighted avg     0.9103    0.9183    0.9121      1053
#
# ------------------------------
#
# Macro-Average Results:
# Macro Precision: 0.8863
# Macro Recall: 0.8247
# Macro F1-Score: 0.8501
#
# Weighted-Average Results:
# Weighted Precision: 0.9315
# Weighted Recall: 0.9335
# Weighted F1-Score: 0.9313

# %% [markdown]
# ### 3.6 Logistic Regression

# %% [markdown]
# #### 3.6.1 Buid Logistic Regression Model (5 folds CV to tune the hyperparameters)

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import make_scorer

# Calculates the mean macro F1-score across 8 labels to as the performance metric for grid search hyperparameter tuning
def mean_macro_f1_score(y_true, y_pred):
    f1s = []
    # Use for loop to calculate macro f1 over 8 label names and their indices
    for i, label in enumerate(full_cols):
        f1 = f1_score(y_true[:, i], y_pred[:, i], average='macro')
        f1s.append(f1)
    return np.mean(f1s)

from sklearn.linear_model import LogisticRegression

perlabel_lr = LogisticRegression(max_iter=1000,random_state=42)
multi_lr = MultiOutputClassifier(perlabel_lr)
# Add the prefix estimator__ to define the hyperparameter search space to  use the multi-output classifie
param_grid_lr = {'estimator__C': [0.01, 0.1, 1, 10, 100]}

grid_search_lr = GridSearchCV(
    estimator=multi_lr,
    param_grid=param_grid_lr,
    cv=5,
    # Use thesame performance score (Macro f1) in the random forest 
    scoring=make_scorer(mean_macro_f1_score),
    verbose=1,
    n_jobs=-1
)

grid_search_lr.fit(X_train_TFIDF, y_train)

print("Best Parameters:")
print(grid_search_lr.best_params_)
print("Best CV Macro F1 Score: " + str(round(grid_search_lr.best_score_, 4)))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best Parameters:
# {'estimator__C': 100}
# Best CV Macro F1 Score: 0.7762

# %% [markdown]
# #### 3.4.2 Test Logistic Regression Performance

# %%
# Make predictions
y_test_pred = grid_search_lr.best_estimator_.predict(X_test_TFIDF)

precision_macro = []
recall_macro = []
f1_macro = []

precision_weighted = []
recall_weighted = []
f1_weighted = []

for i, label in enumerate(full_cols):
    print(f"\nLabel: {label}")
    print(classification_report(y_test[:, i], y_test_pred[:, i], digits=4))

    # macro
    prec = precision_score(y_test[:, i], y_test_pred[:, i], average='macro')
    rec = recall_score(y_test[:, i], y_test_pred[:, i], average='macro')
    f1 = f1_score(y_test[:, i], y_test_pred[:, i], average='macro')

    precision_macro.append(prec)
    recall_macro.append(rec)
    f1_macro.append(f1)

    # weighted
    prec_w = precision_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    rec_w = recall_score(y_test[:, i], y_test_pred[:, i], average='weighted')
    f1_w = f1_score(y_test[:, i], y_test_pred[:, i], average='weighted')

    precision_weighted.append(prec_w)
    recall_weighted.append(rec_w)
    f1_weighted.append(f1_w)

# The macro precision, recall, and F1-score were computed by averaging the per-label macro scores in the above classification report
print("-" * 30)
print("\nMacro-Average Results:")
print("Macro Precision: " + str(round(sum(precision_macro) / len(precision_macro), 4)))
print("Macro Recall: " + str(round(sum(recall_macro) / len(recall_macro), 4)))
print("Macro F1-Score: " + str(round(sum(f1_macro) / len(f1_macro), 4)))


# The weighted scores were computed by averaging the per-label weighted scores in the above classification report
print("\nWeighted-Average Results:")
print(f"Weighted Precision: {sum(precision_weighted) / len(precision_weighted):.4f}")
print(f"Weighted Recall: {sum(recall_weighted) / len(recall_weighted):.4f}")
print(f"Weighted F1-Score: {sum(f1_weighted) / len(f1_weighted):.4f}")
# Out:
# Label: sdoh_community_present
#               precision    recall  f1-score   support
#
#            0     0.9324    0.9008    0.9163       383
#            1     0.9444    0.9627    0.9534       670
#
#     accuracy                         0.9402      1053
#    macro avg     0.9384    0.9317    0.9349      1053
# weighted avg     0.9400    0.9402    0.9399      1053
#
#
# Label: sdoh_community_absent
#               precision    recall  f1-score   support
#
#            0     0.9556    0.9893    0.9721       935
#            1     0.8824    0.6356    0.7389       118
#
#     accuracy                         0.9497      1053
#    macro avg     0.9190    0.8124    0.8555      1053
# weighted avg     0.9474    0.9497    0.9460      1053
#
#
# Label: sdoh_education
#               precision    recall  f1-score   support
#
#            0     0.9865    0.9990    0.9927      1022
#            1     0.9444    0.5484    0.6939        31
#
#     accuracy                         0.9858      1053
#    macro avg     0.9655    0.7737    0.8433      1053
# weighted avg     0.9852    0.9858    0.9839      1053
#
#
# Label: sdoh_economics
#               precision    recall  f1-score   support
#
#            0     0.9339    0.9673    0.9503       643
#            1     0.7857    0.7432    0.7639       148
#            2     0.8988    0.8473    0.8723       262
#
#     accuracy                         0.9060      1053
#    macro avg     0.8728    0.8526    0.8622      1053
# weighted avg     0.9044    0.9060    0.9047      1053
#
#
# Label: sdoh_environment
#               precision    recall  f1-score   support
#
#            0     0.9541    0.9565    0.9553       391
#            1     0.9695    0.9724    0.9709       653
#            2     1.0000    0.6667    0.8000         9
#
#     accuracy                         0.9639      1053
#    macro avg     0.9745    0.8652    0.9087      1053
# weighted avg     0.9640    0.9639    0.9637      1053
#
#
# Label: behavior_alcohol
#               precision    recall  f1-score   support
#
#            0     0.9231    0.9194    0.9212       248
#            1     0.8228    0.8360    0.8293       311
#            2     0.5672    0.4935    0.5278        77
#            3     0.8196    0.8665    0.8424       367
#            4     0.6857    0.4800    0.5647        50
#
#     accuracy                         0.8243      1053
#    macro avg     0.7637    0.7191    0.7371      1053
# weighted avg     0.8201    0.8243    0.8209      1053
#
#
# Label: behavior_tobacco
#               precision    recall  f1-score   support
#
#            0     0.8223    0.8394    0.8308       193
#            1     0.7113    0.6689    0.6894       151
#            2     0.8498    0.8365    0.8431       318
#            3     0.7895    0.8432    0.8155       338
#            4     0.6000    0.4528    0.5161        53
#
#     accuracy                         0.7958      1053
#    macro avg     0.7546    0.7282    0.7390      1053
# weighted avg     0.7930    0.7958    0.7935      1053
#
#
# Label: behavior_drug
#               precision    recall  f1-score   support
#
#            0     0.9072    0.9536    0.9298       646
#            1     0.5000    0.3226    0.3922        31
#            2     0.5455    0.3636    0.4364        33
#            3     0.8567    0.8754    0.8659       321
#            4     0.2500    0.0455    0.0769        22
#
#     accuracy                         0.8737      1053
#    macro avg     0.6119    0.5121    0.5402      1053
# weighted avg     0.8548    0.8737    0.8612      1053
#
# ------------------------------
#
# Macro-Average Results:
# Macro Precision: 0.85
# Macro Recall: 0.7744
# Macro F1-Score: 0.8026
#
# Weighted-Average Results:
# Weighted Precision: 0.9011
# Weighted Recall: 0.9049
# Weighted F1-Score: 0.9017

# %% [markdown]
# # Task 4
# ## Neuro Network Models

# %% [markdown]
# ## 4.1 CNN

# %% [markdown]
# In this part, I used the popular neural network API Keras that I learned from the course to build a CNN classifer to classify sentences in PubMed RCT abstracts. I uses the TensorFlow, which is a very widely used machine learning library to biuld deep learning models.

# %% [markdown]
# A TensorFlow environment was set up in my Jupyter Notebook to get a correct and consistent computational environment. This environment was activated using Conda, and many different essential tools were installed to do these analysis that I need. And this environment is saved as a Jupyter kernel in my computer.

# %% [markdown]
# ### 4.1.1 Import Packages & Setup
# First, I installed the  TensorFlow library to enable building and training deep learning models.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import Callback

from sklearn.metrics import f1_score
import matplotlib.pyplot as plt

# %%
# %pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (2.32.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.3-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\programdata\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.3.5)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.17.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Downloading tensorflow-2.19.0-cp312-cp312-win_amd64.whl (376.0 MB)
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 1.5/376.0 MB 31.8 MB/s eta 0:00:12
#     --------------------------------------- 6.2/376.0 MB 66.0 MB/s eta 0:00:06
#     --------------------------------------- 7.3/376.0 MB 51.4 MB/s eta 0:00:08
#     --------------------------------------- 8.2/376.0 MB 43.6 MB/s eta 0:00:09
#     --------------------------------------- 9.2/376.0 MB 39.1 MB/s eta 0:00:10
#    - -------------------------------------- 13.4/376.0 MB 46.7 MB/s eta 0:00:08
#    - -------------------------------------- 18.3/376.0 MB 65.6 MB/s eta 0:00:06
#    -- ------------------------------------ 22.5/376.0 MB 108.8 MB/s eta 0:00:04
#    -- ------------------------------------- 26.1/376.0 MB 93.0 MB/s eta 0:00:04
#    --- ------------------------------------ 30.4/376.0 MB 93.9 MB/s eta 0:00:04
#    --- ------------------------------------ 34.6/376.0 MB 93.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 38.8/376.0 MB 93.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 42.9/376.0 MB 81.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 47.0/376.0 MB 81.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 51.0/376.0 MB 81.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 55.2/376.0 MB 81.8 MB/s eta 0:00:04
#    ------ --------------------------------- 59.4/376.0 MB 81.8 MB/s eta 0:00:04
#    ------ --------------------------------- 63.6/376.0 MB 93.9 MB/s eta 0:00:04
#    ------- -------------------------------- 68.2/376.0 MB 93.9 MB/s eta 0:00:04
#    ------- -------------------------------- 72.4/376.0 MB 81.8 MB/s eta 0:00:04
#    -------- ------------------------------- 76.6/376.0 MB 93.0 MB/s eta 0:00:04
#    -------- ------------------------------- 80.9/376.0 MB 93.0 MB/s eta 0:00:04
#    --------- ------------------------------ 85.3/376.0 MB 93.9 MB/s eta 0:00:04
#    --------- ------------------------------ 89.5/376.0 MB 93.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 94.0/376.0 MB 93.9 MB/s eta 0:00:04
#    ---------- -----------------------------
# Downloading absl_py-2.3.1-py3-none-any.whl (135 kB)
#    ---------------------------------------- 0.0/135.8 kB ? eta -:--:--
#    ---------------------------------------  133.1/135.8 kB ? eta -:--:--
#    ---------------------------------------- 135.8/135.8 kB 2.7 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB 1.5 MB/s eta 0:00:00
# Downloading grpcio-1.74.0-cp312-cp312-win_amd64.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------- ----------- 3.2/4.5 MB 101.4 MB/s eta 0:00:01
#    ---------------------------------------  4.5/4.5 MB 71.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 47.7 MB/s eta 0:00:00
# Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------  1.4/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 29.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ----- ---------------------------------- 3.5/26.4 MB 111.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 7.0/26.4 MB 89.0 MB/s eta 0:00:01
#    --------------- ------------------------ 10.5/26.4 MB 81.8 MB/s eta 0:00:01
#    --------------------- ------------------ 14.1/26.4 MB 72.6 MB/s eta 0:00:01
#    -------------------------- ------------- 17.5/26.4 MB 81.8 MB/s eta 0:00:01
#    ------------------------------- -------- 20.6/26.4 MB 73.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.6/26.4 MB 72.6 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 73.1 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 73.1 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 50.4 MB/s eta 0:00:00
# Downloading ml_dtypes-0.5.3-cp312-cp312-win_amd64.whl (208 kB)
#    ---------------------------------------- 0.0/208.2 kB ? eta -:--:--
#    ---------------------------------------- 208.2/208.2 kB 6.4 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 1.3 MB/s eta 0:00:00
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------------------------- ------------ 3.7/5.5 MB 120.6 MB/s eta 0:00:01
#    ---------------------------------------  5.5/5.5 MB 116.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 59.1 MB/s eta 0:00:00
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.17.0-cp312-cp312-win_amd64.whl (314 kB)
#    ---------------------------------------- 0.0/314.1 kB ? eta -:--:--
#    ---------------------------------------  307.2/314.1 kB ? eta -:--:--
#    ---------------------------------------- 314.1/314.1 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorboard-data-server, optree, opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow
# Successfully installed absl-py-2.3.1 astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 grpcio-1.74.0 keras-3.10.0 libclang-18.1.1 ml-dtypes-0.5.3 namex-0.1.0 opt-einsum-3.4.0 optree-0.17.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 termcolor-3.1.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\k24034365\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe and toco.exe are installed in 'C:\Users\k24034365\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ### 4.1.2 Parameters for CNN
#
# After extensive experimentation and comparison of various hyperparameter settings, I identified the following parameter values to balance model complexity and generalization ability effectively for this CNN model:
#
# 1) Batch size: 32 (the number of documents processed during training)
# 2) Sequence length: 100
# 3) Max features: 5000
# 4) Embedding dimension: 96 (number of dimensions in the word embedding space)
# 5) Embedding dropout: 0.2 (embedding layer dropout rate)
# 6) Filters: 32 (the number of output filters in the convolutional layer)
# 7) Kernel size: 3 (Length of the convolution window)
# 8) Dense dropout: 0.3 (dense hidden layer dropout rate)
# 9) Hidden units: 64
# 10) Epochs: 100
#
# These parameters were set to balance model complexity and generalization ability effectively for our dataset.

# %%
# Set these parameters to improve the accuracy on the validation dataset
max_feature = 5500
embedding_dim = 96
embedding_dropout = 0.25
filters = 128
kernel_size = 3
dense_dropout = 0.25
hidden_units = 64
sequence_length = 60
batch_size = 32
epochs = 128

# %% [markdown]
# ### 4.1.3 Vectorization & Convert to tensors (Prepare labels and text data for multi-task CNN model)

# %% [markdown]
# Vectorise the text:
#
# I create a TextVectorization layer to convert raw text into token sequences suitable for input into the neural network, and then adapt method on the training texts that allows the layer to build a vocabulary from the training dataset.
#
# Next, I use a function to converts Pandas DataFrame into a TensorFlow dataset object. This makes it convenient to enable efficient training in the next step.

# %%
from collections import Counter
all_text = " ".join(data_train['clean_social_history'].values)
word_counts = Counter(all_text.split())
print(len(word_counts))  # Set max_feature as 5500
# Out:
# 5422

# %% [markdown]
# ##### Text Vectorization

# %%
vectorize_layer = layers.TextVectorization(
    max_tokens=max_feature,
    output_mode='int',
    output_sequence_length=sequence_length
)

train_texts = data_train['clean_social_history'].tolist()
val_texts = data_val['clean_social_history'].tolist()
test_texts = data_test['clean_social_history'].tolist()

# Directly adapt the TextVectorization layer on the preprocessed cleaned text
vectorize_layer.adapt(train_texts)

# %%
# Extracts label arrays for eight tasks from training and validation data
train_ylist = [data_train[col].values for col in full_cols]
val_ylist = [data_val[col].values for col in full_cols]

# Convert the training and validation text lists into TensorFlow string tensors
train_texts_tensor = tf.convert_to_tensor(np.array(train_texts).reshape(-1,1), dtype=tf.string)
val_texts_tensor = tf.convert_to_tensor(np.array(val_texts).reshape(-1,1), dtype=tf.string)

# %% [markdown]
# ### 4.1.4 Alter the Multi-Task CNN Model

# %% [markdown]
# These are the steps altering the model to try to improve the performances
#
# ·    Add new layers into the model and changed the width of the layers, and both have ReLu activation
#
# ·    Add the early stopping
#
# ·    Add dropout layers（0.25）
#
# ·    Reduce the batch size to 32
#
# ·    Add L2 regularization

# %%
def create_cnn_multitask():
    inputs = layers.Input(shape=(1,), dtype=tf.string)
    x = vectorize_layer(inputs)
    x = layers.Embedding(max_feature, embedding_dim)(x)
    x = layers.Dropout(embedding_dropout)(x)
    x = layers.Conv1D(filters=filters, kernel_size=2, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv1D(filters=filters, kernel_size=3, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    # model.add(layers.Conv1D(filters=filters, kernel_size=kernel_size1, activation='relu'))
    # model.add(layers.Conv1D(filters=filters, kernel_size=kernel_size2, activation='relu'))
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dense(hidden_units, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(dense_dropout)(x)
    # As this is a multi-task model, set 8 output layers based on the same CNN learning layers
    outputs = [
        layers.Dense(2, activation='softmax', name='sdoh_community_present')(x),
        layers.Dense(2, activation='softmax', name='sdoh_community_absent')(x),
        layers.Dense(2, activation='softmax', name='sdoh_education')(x),
        layers.Dense(3, activation='softmax', name='sdoh_economics')(x),
        layers.Dense(3, activation='softmax', name='sdoh_environment')(x),
        layers.Dense(5, activation='softmax', name='behavior_alcohol')(x),
        layers.Dense(5, activation='softmax', name='behavior_tobacco')(x),
        layers.Dense(5, activation='softmax', name='behavior_drug')(x)
    ]

    return models.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/keras/metrics.py

# %% [markdown]
# #### Set up validation metric monitoring
#
# Define two custom metric classes, BinaryF1 and MacroF1, to calculate the F1 score for binary and multi-class tasks, respectively, and assigns the corresponding validation metrics for each task.

# %%
# Define custom metrics for monitoring

# ① Calculate F1 score for class 1 in binary classification tasks

class BinaryF1(tf.keras.metrics.Metric):
    def __init__(self, name='binary_f1', **kwargs):
        super().__init__(name=name, **kwargs)
        self.tp = self.add_weight(name='tp', initializer='zeros')
        self.fp = self.add_weight(name='fp', initializer='zeros')
        self.fn = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred_label = tf.argmax(y_pred, axis=-1)
        y_true = tf.cast(y_true, tf.int64)

        tp = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_pred_label, 1), tf.equal(y_true, 1)), tf.float32))
        fp = tf.reduce_sum(tf.cast(tf.logical_and(tf.equal(y_pred_label, 1), tf.not_equal(y_true, 1)), tf.float32))
        fn = tf.reduce_sum(tf.cast(tf.logical_and(tf.not_equal(y_pred_label, 1), tf.equal(y_true, 1)), tf.float32))

        self.tp.assign_add(tp)
        self.fp.assign_add(fp)
        self.fn.assign_add(fn)

    def result(self):
        precision = self.tp / (self.tp + self.fp + 1e-7)
        recall = self.tp / (self.tp + self.fn + 1e-7)
        return 2 * precision * recall / (precision + recall + 1e-7)

    def reset_states(self):
        self.tp.assign(0.)
        self.fp.assign(0.)
        self.fn.assign(0.)

# ②Calculate macro F1 score for multi-class classification tasks
class MacroF1(tf.keras.metrics.Metric):
    def __init__(self, num_classes, name='macro_f1', **kwargs):
        super().__init__(name=name, **kwargs)
        self.num_classes = num_classes
        self.tp = self.add_weight(shape=(num_classes,), initializer='zeros', name='tp')
        self.fp = self.add_weight(shape=(num_classes,), initializer='zeros', name='fp')
        self.fn = self.add_weight(shape=(num_classes,), initializer='zeros', name='fn')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred_label = tf.argmax(y_pred, axis=-1)
        y_true = tf.cast(y_true, tf.int32)

        for i in range(self.num_classes):
            y_true_i = tf.equal(y_true, i)
            y_pred_i = tf.equal(y_pred_label, i)

            tp = tf.reduce_sum(tf.cast(tf.logical_and(y_true_i, y_pred_i), tf.float32))
            fp = tf.reduce_sum(tf.cast(tf.logical_and(tf.logical_not(y_true_i), y_pred_i), tf.float32))
            fn = tf.reduce_sum(tf.cast(tf.logical_and(y_true_i, tf.logical_not(y_pred_i)), tf.float32))

            #self.tp.assign(tf.tensor_scatter_nd_add(self.tp, [[i]], [tp]))
            #self.fp.assign(tf.tensor_scatter_nd_add(self.fp, [[i]], [fp]))
            #self.fn.assign(tf.tensor_scatter_nd_add(self.fn, [[i]], [fn]))

            self.tp.assign_add(tf.one_hot(i, self.num_classes) * tp)
            self.fp.assign_add(tf.one_hot(i, self.num_classes) * fp)
            self.fn.assign_add(tf.one_hot(i, self.num_classes) * fn)


    def result(self):
        precision = self.tp / (self.tp + self.fp + 1e-7)
        recall = self.tp / (self.tp + self.fn + 1e-7)
        f1 = 2 * precision * recall / (precision + recall + 1e-7)
        return tf.reduce_mean(f1)

    def reset_states(self):
        self.tp.assign(tf.zeros_like(self.tp))
        self.fp.assign(tf.zeros_like(self.fp))
        self.fn.assign(tf.zeros_like(self.fn))

# Set up metrics to monitor on the validation set for each task each epoch
metrics={}
num_classes_dict = {name: len(columns[name]) for name in full_cols}

for name in full_cols:
    # Binary
    if name in binary_cls_cols:
        metrics[name] = [BinaryF1(name = 'f1')]
    # Multi-class classification:
    else:
        metrics[name] = [MacroF1(num_classes=num_classes_dict[name], name='macro_f1')]

# %% [markdown]
# #### Add Early Stop

# %% [markdown]
# ##### https://medium.com/biased-algorithms/a-practical-guide-to-implementing-early-stopping-in-pytorch-for-model-training-99a7cbd46e9d

# %% [markdown]
# MultiMetricEarlyStopping Callback：
#
# As this is a multi-task learning with imbalanced data, a callback based on multiple validation F1-score metrics is used.
# It averages these F1 scores each epoch and stops training if the average doesn't improve for a given 15 patience.

# %%
class MultiMetricEarlyStopping(Callback):
    def __init__(self, monitor_metrics, patience=5):
        
        super().__init__()
        self.monitor_metrics = monitor_metrics
        self.patience = patience
        self.wait = 0
        self.best = None
        self.stopped_epoch = 0
    
    def on_train_begin(self, logs=None):
        self.wait = 0
        self.stopped_epoch = 0
        self.best = -np.inf
            
    # Use logs to get metric values of the current epoch, average them, then compare with the best 
    def on_epoch_end(self, epoch, logs=None):


        # Get the current epoch's values for all metrics and then simply calculate the mean value
        current_metrics = []
        for metric_name in self.monitor_metrics:
            value = logs.get(metric_name)
            current_metrics.append(value)
        
        current_score = np.mean(current_metrics)

        if current_score > self.best:
            # Current combined metric improved, update the best score and reset patience wait counter
            self.best = current_score
            self.wait = 0
            print(f"[Epoch {epoch+1}] Combined metric improved to {self.best:.4f};  reset wait counter")
            print("-" * 30)
        else:
            # There is no improvement, increase patient wait counter
            self.wait += 1
            print(f"[Epoch {epoch+1}] No improvement (current {current_score:.4f}, best {self.best:.4f}), wait {self.wait}/{self.patience}")
            print("-" * 30)
            if self.wait >= self.patience:
                self.stopped_epoch = epoch + 1
                self.model.stop_training = True

                print(f"Training stopped early as there is no improvement for {self.patience} epochs\n So END Training.")

early_stop = MultiMetricEarlyStopping(
    monitor_metrics = [
    'val_behavior_alcohol_macro_f1',
    'val_behavior_drug_macro_f1',
    'val_behavior_tobacco_macro_f1',
    'val_sdoh_community_absent_f1',
    'val_sdoh_community_present_f1',
    'val_sdoh_economics_macro_f1',
    'val_sdoh_education_f1',
    'val_sdoh_environment_macro_f1',
],
    patience=15,
)

# %% [markdown]
# #### 4.1.5 Compile the module

# %%
model10 = create_cnn_multitask()

model10.compile(
    optimizer='adam',
    loss={name: 'sparse_categorical_crossentropy' for name in full_cols},
    metrics=metrics
)

# %%
history_10 = model10.fit(
    train_texts_tensor,
    train_ylist,
    validation_data=(val_texts_tensor, val_ylist),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=2
)
# Out:
# Epoch 1/128
# [Epoch 1] Combined metric improved to 0.0691;  reset wait counter
# ------------------------------
# Epoch 27/128
# [Epoch 27] No improvement (current 0.7891, best 0.7917), wait 1/15
# ------------------------------
# 154/154 - 1s - 9ms/step - behavior_alcohol_loss: 0.2072 - behavior_alcohol_macro_f1: 0.8655 - behavior_drug_loss: 0.1712 - behavior_drug_macro_f1: 0.7865 - behavior_tobacco_loss: 0.2293 - behavior_tobacco_macro_f1: 0.8918 - loss: 0.9736 - sdoh_community_absent_f1: 0.9089 - sdoh_community_absent_loss: 0.0570 - sdoh_community_present_f1: 0.9777 - sdoh_community_present_loss: 0.0818 - sdoh_economics_loss: 0.1211 - sdoh_economics_macro_f1: 0.9419 - sdoh_education_f1: 0.7899 - sdoh_education_loss: 0.0321 - sdoh_environment_loss: 0.0658 - sdoh_environment_macro_f1: 0.9145 - val_behavior_alcohol_loss: 0.4372 - val_behavior_alcohol_macro_f1: 0.7950 - val_behavior_drug_loss: 0.2939 - val_behavior_drug_macro_f1: 0.5864 - val_behavior_tobacco_loss: 0.4993 - val_behavior_tobacco_macro_f1: 0.8266 - val_loss: 2.1495 - val_sdoh_community_absent_f1: 0.8843 - val_sdoh_community_absent_loss: 0.0987 - val_sdoh_community_present_f1: 0.9541 - val_sdoh_community_present_loss: 0.2001 - val_sdoh_economics_loss: 0.3797 - val_sdoh_economics_macro_f1: 0.8862 - val_sdoh_education_f1: 0.5417 - val_sdoh_education_loss: 0.0705 - val_sdoh_environment_loss: 0.1622 - val_sdoh_environment_macro_f1: 0.8383
# Epoch 28/128
# [Epoch 28] Combined metric improved to 0.7970;  reset wait counter
# ------------------------------
# 154/154 - 1s - 8ms/step - behavior_alcohol_loss: 0.2091 - behavior_alcohol_macro_f1: 0.8747 - behavior_drug_loss: 0.1719 - behavior_drug_macro_f1: 0.7756 - behavior_tobacco_loss: 0.2134 - behavior_tobacco_macro_f1: 0.8999 - loss: 0.9736 - sdoh_community_absent_f1: 0.8983 - sdoh_community_absent_loss: 0.0611 - sdoh_community_present_f1: 0.9784 - sdoh_community_present_loss: 0.0801 - sdoh_economics_loss: 0.1244 - sdoh_economics_macro_f1: 0.9387 - sdoh_education_f1: 0.7899 - sdoh_education_loss: 0.0285 - sdoh_environment_loss: 0.0794 - sdoh_environment_macro_f1: 0.9004 - val_behavior_alcohol_loss: 0.4341 - val_behavior_alcohol_macro_f1: 0.7871 - val_behavior_drug_loss: 0.2715 - val_behavior_drug_macro_f1: 0.6524 - val_behavior_tobacco_loss: 0.5104 - val_behavior_tobacco_macro_f1: 0.8262 - val_loss: 2.0546 - val_sdoh_community_absent_f1: 0.8755 - val_sdoh_community_absent_loss: 0.0850 - val_sdoh_community_present_f1: 0.9632 - val_sdoh_community_present_loss: 0.1776 - val_sdoh_economics_loss: 0.3487 - val_sdoh_economics_macro_f1: 0.8860 - val_sdoh_education_f1: 0.5490 - val_sdoh_education_loss: 0.0673 - val_sdoh_environment_loss: 0.1524 - val_sdoh_environment_macro_f1: 0.8369
# Epoch 29/128
# [Epoch 29] No improvement (current 0.7916, best 0.7970), wait 1/15
# ------------------------------
# 154/154 - 1s - 9ms/step - behavior_alcohol_loss:
# ------------------------------
# Training stopped early as there is no improvement for 15 epochs
#  So END Training.
# 154/154 - 1s - 9ms/step - behavior_alcohol_loss: 0.1135 - behavior_alcohol_macro_f1: 0.9341 - behavior_drug_loss: 0.1110 - behavior_drug_macro_f1: 0.8497 - behavior_tobacco_loss: 0.1303 - behavior_tobacco_macro_f1: 0.9353 - loss: 0.5483 - sdoh_community_absent_f1: 0.9455 - sdoh_community_absent_loss: 0.0275 - sdoh_community_present_f1: 0.9911 - sdoh_community_present_loss: 0.0368 - sdoh_economics_loss: 0.0656 - sdoh_economics_macro_f1: 0.9669 - sdoh_education_f1: 0.8935 - sdoh_education_loss: 0.0150 - sdoh_environment_loss: 0.0401 - sdoh_environment_macro_f1: 0.9391 - val_behavior_alcohol_loss: 0.5636 - val_behavior_alcohol_macro_f1: 0.8173 - val_behavior_drug_loss: 0.3411 - val_behavior_drug_macro_f1: 0.6624 - val_behavior_tobacco_loss: 0.6367 - val_behavior_tobacco_macro_f1: 0.8382 - val_loss: 2.7479 - val_sdoh_community_absent_f1: 0.9000 - val_sdoh_community_absent_loss: 0.1159 - val_sdoh_community_present_f1: 0.9652 - val_sdoh_community_present_loss: 0.2401 - val_sdoh_economics_loss: 0.4822 - val_sdoh_economics_macro_f1: 0.8974 - val_sdoh_education_f1: 0.6296 - val_sdoh_education_loss: 0.1200 - val_sdoh_environment_loss: 0.2397 - val_sdoh_environment_macro_f1: 0.9095

# %% [markdown]
# #### 4.1.6 Test CNN Performance

# %%
# Smae as above, Convert the training and validation text lists into TensorFlow string tensors
test_texts_tensor = tf.convert_to_tensor(np.array(test_texts).reshape(-1, 1), dtype=tf.string)
# Smae as above, extracts label arrays for eight tasks from training and validation data
test_ylist = [data_test[col].values for col in full_cols]

# 模型预测
y_test_preds = model10.predict(test_texts_tensor)
y_test_pred_labels = [np.argmax(pred, axis=1) for pred in y_test_preds]

precision_macro = []
recall_macro = []
f1_macro = []
accuracy_list = []

precision_weighted = []
recall_weighted = []
f1_weighted = []

for i, label in enumerate(full_cols):
    y_true = test_ylist[i]
    y_pred = y_test_pred_labels[i]

    print(f"\nLabel: {label}")
    print(classification_report(test_ylist[i], y_test_pred_labels[i], digits=4))

    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    acc = accuracy_score(y_true, y_pred)

    precision_macro.append(precision)
    recall_macro.append(recall)
    f1_macro.append(f1)
    accuracy_list.append(acc)

    precision_w = precision_score(y_true, y_pred, average='weighted')
    recall_w = recall_score(y_true, y_pred, average='weighted')
    f1_w = f1_score(y_true, y_pred, average='weighted')

    precision_weighted.append(precision_w)
    recall_weighted.append(recall_w)
    f1_weighted.append(f1_w)

print("\nCNN Macro-Average Results:")
print(f"Macro Precision: {np.mean(precision_macro):.4f}")
print(f"Macro Recall:    {np.mean(recall_macro):.4f}")
print(f"Macro F1-Score:  {np.mean(f1_macro):.4f}")
print(f"Macro Accuracy:  {np.mean(accuracy_list):.4f}")

print("\nCNN Weighted-Average Results:")
print(f"Weighted Precision: {sum(precision_weighted) / len(precision_weighted):.4f}")
print(f"Weighted Recall: {sum(recall_weighted) / len(recall_weighted):.4f}")
print(f"Weighted F1-Score: {sum(f1_weighted) / len(f1_weighted):.4f}")

# Clear Classific Refort
print("\nCNN Detailed Task-wise Evaluation:")
for i, name in enumerate(full_cols):
    print(f"{name:<25} | Acc: {accuracy_list[i]:.4f} | Prec: {precision_macro[i]:.4f} | Rec: {recall_macro[i]:.4f} | F1: {f1_macro[i]:.4f}")
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Label: sdoh_community_present
#               precision    recall  f1-score   support
#
#            0     0.9778    0.9191    0.9475       383
#            1     0.9553    0.9881    0.9714       670
#
#     accuracy                         0.9630      1053
#    macro avg     0.9665    0.9536    0.9594      1053
# weighted avg     0.9635    0.9630    0.9627      1053
#
#
# Label: sdoh_community_absent
#               precision    recall  f1-score   support
#
#            0     0.9840    0.9882    0.9861       935
#            1     0.9035    0.8729    0.8879       118
#
#     accuracy                         0.9753      1053
#    macro avg     0.9438    0.9306    0.9370      1053
# weighted avg     0.9750    0.9753    0.9751      1053
#
#
# Label: sdoh_education
#               precision    recall  f1-score   support
#
#            0     0.9913    0.9990    0.9951      1022
#            1     0.9565    0.7097    0.8148        31
#
#     accuracy                         0.9905      1053
#    macro avg     0.9739    0.8543    0.9050      1053
# weighted avg     0.9902    0.9905    0.9898      1053
#
#
# Label: sdoh_economics
#               precision    recall  f1-score   support
#
#            0     0.9653    0.9518    0.9585       643
#            1     0.7959    0.7905    0.7932       148
#            2     0.8824    0.9160    0.8989       262
#
#     accuracy                         0.9202      1053
#    macro avg     0.8812    0.8861    0.8835      1053
# weighted avg     0.9209    0.9202    0.9204      1053
#
#
# Label: sdoh_environment
#               precision    recall  f1-score   support
#
#            0     0.9839    0.9361    0.9594       391
#            1     0.9585    0.9908    0.9744       653
#            2     1.0000    0.6667    0.8000         9
#
#     accuracy                         0.9677      1053
#    macro avg     0.9808    0.8645    0.9113      1053
# weighted avg     0.9683    0.9677    0.9673      1053
#
#
# Label: behavior_alcohol
#               precision    recall  f1-score   support
#
#            0     0.9544    0.9274    0.9407       248
#            1     0.8669    0.9421    0.9029       311
#            2     0.7463    0.6494    0.6944        77
#            3     0.9268    0.9319    0.9293       367
#            4     0.7105    0.5400    0.6136        50
#
#     accuracy                         0.8946      1053
#    macro avg     0.8410    0.7982    0.8162      1053
# weighted avg     0.8921    0.8946    0.8920      1053
#
#
# Label: behavior_tobacco
#               precision    recall  f1-score   support
#
#            0     0.9351    0.8964    0.9153       193
#            1     0.8201    0.7550    0.7862       151
#            2     0.9021    0.9277    0.9147       318
#            3     0.8980    0.9379    0.9175       338
#            4     0.7755    0.7170    0.7451        53
#
#     accuracy                         0.8898      1053
#    macro avg     0.8662    0.8468    0.8558      1053
# weighted avg     0.8887    0.8898    0.8888      1053
#
#
# Label: behavior_drug
#               precision    recall  f1-score   support
#
#            0     0.9921    0.9768    0.9844       646
#            1     0.4000    0.3226    0.3571        31
#            2     0.6154    0.4848    0.5424        33
#            3     0.8983    0.9907    0.9422       321
#            4     0.5833    0.3182    0.4118        22
#
#     accuracy                         0.9326      1053
#    macro avg     0.6978    0.6186    0.6476      1053
# weighted avg     0.9258    0.9326    0.9273      1053
#
#
# CNN Macro-Average Results:
# Macro Precision: 0.8939
# Macro Recall:    0.8441
# Macro F1-Score:  0.8645
# Macro Accuracy:  0.9417
#
# CNN Weighted-Average Results:
# Weighted Precision: 0.9406
# Weighted Recall: 0.9417
# Weighted F1-Score: 0.9404
#
# CNN Detailed Task-wise Evaluation:
# sdoh_community_present    | Acc: 0.9630 | Prec: 0.9665 | Rec: 0.9536 | F1: 0.9594
# sdoh_community_absent     | Acc: 0.9753 | Prec: 0.9438 | Rec: 0.9306 | F1: 0.9370
# sdoh_education            | Acc: 0.9905 | Prec: 0.9739 | Rec: 0.8543 | F1: 0.9050
# sdoh_economics            | Acc: 0.9202 | Prec: 0.8812 | Rec: 0.8861 | F1: 0.8835
# sdoh_environment          | Acc: 0.9677 | Prec: 0.9808 | Rec: 0.8645 | F1: 0.9113
# behavior_alcohol          | Acc: 0.8946 | Prec: 0.8410 | Rec: 0.7982 | F1: 0.8162
# behavior_tobacco          | Acc: 0.8898 | Prec: 0.8662 | Rec: 0.8468 | F1: 0.8558
# behavior_drug             | Acc: 0.9326 | Prec: 0.6978 | Rec: 0.6186 | F1: 0.6476

# %% [markdown]
# ## 4.2 LSTM

# %% [markdown]
# Then I build a BiLSTM model that could incorporate the current sentence along with its context, and it might be better at capturing long-range dependencies in text.

# %% [markdown]
# ### 4.1.2 Parameters for LSTM
#
# After extensive experimentation and comparison of various hyperparameter settings, I identified the following parameter values to balance model complexity and generalization ability effectively for this CNN model:
#
# 1) Batch size: 32 (the number of documents processed during training)
# 2) Sequence length: 100
# 3) Max features: 5000
# 4) Embedding dimension: 96 (number of dimensions in the word embedding space)
# 5) Embedding dropout: 0.2 (embedding layer dropout rate)
# 6) Filters: 32 (the number of output filters in the convolutional layer)
# 7) Kernel size: 3 (Length of the convolution window)
# 8) Dense dropout: 0.3 (dense hidden layer dropout rate)
# 9) Hidden units: 64
# 10) Epochs: 100
#
# These parameters were set to balance model complexity and generalization ability effectively for our dataset.

# %%
# Set these parameters to improve the accuracy on the validation dataset
# max_feature = 5000
# embedding_dim = 96
# embedding_dropout = 0.25
# filters = 128
# kernel_size = 3
# dense_dropout = 0.25
# hidden_units = 64
# sequence_length = 60
# batch_size = 32
# epochs = 128

# %%
# Set these parameters to improve the accuracy on the validation dataset
max_feature = 5500
embedding_dim = 96
embedding_dropout = 0.2
dense_dropout = 0.4
hidden_units = 64
sequence_length = 60
batch_size = 32
epochs = 128

# %% [markdown]
# ### 4.2.1 Alter the Multi-Task LSTM Model

# %% [markdown]
# These are the steps altering the model to try to improve the performances
#
# · Add new layers into the model and changed the width of the layers, and both have ReLu activation
#
# · Add the early stopping
#
# · Add dropout layers（0.25）
#
# · Reduce the batch size to 32
#
# · Add L2 regularization

# %% [markdown]
# #### 4.1.5 Compile the module

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

max_feature = 5500
embedding_dim = 96
embedding_dropout = 0.2
dense_dropout = 0.4
hidden_units = 128
sequence_length = 60

def bilstm2():
    inputs = layers.Input(shape=(1,), dtype=tf.string)
    x = vectorize_layer(inputs)

    x = layers.Embedding(input_dim=max_feature, output_dim=embedding_dim)(x)
    #x = layers.Dropout(embedding_dropout)(x)
    x = layers.SpatialDropout1D(embedding_dropout)(x)

    x = layers.Bidirectional(layers.LSTM(units=64, return_sequences=True))(x)
    x = layers.Bidirectional(layers.LSTM(units=64, return_sequences=True))(x)
    x = layers.MultiHeadAttention(num_heads=4, key_dim=64)(x, x)
    x = layers.GlobalAveragePooling1D()(x)

    x = layers.Dense(hidden_units, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(dense_dropout)(x)
    x = layers.Dense(64, activation='relu')(x)


    outputs = [
        layers.Dense(2, activation='softmax', name='sdoh_community_present')(x),
        layers.Dense(2, activation='softmax', name='sdoh_community_absent')(x),
        layers.Dense(2, activation='softmax', name='sdoh_education')(x),
        layers.Dense(3, activation='softmax', name='sdoh_economics')(x),
        layers.Dense(3, activation='softmax', name='sdoh_environment')(x),
        layers.Dense(5, activation='softmax', name='behavior_alcohol')(x),
        layers.Dense(5, activation='softmax', name='behavior_tobacco')(x),
        layers.Dense(5, activation='softmax', name='behavior_drug')(x)
    ]

    return models.Model(inputs=inputs, outputs=outputs)

# %%
model_lstm6 = bilstm2()

model_lstm6.compile(
    optimizer='adam',
    loss={name: 'sparse_categorical_crossentropy' for name in full_cols},
    metrics=metrics
)

# %%
history_lstm6 = model_lstm6.fit(
    x = train_texts_tensor,
    y = train_ylist,
    validation_data=(val_texts_tensor, val_ylist),
    epochs=epochs,
    batch_size=batch_size,
    callbacks=[early_stop],
    verbose=2
)
# Out:
# Epoch 1/128
# [Epoch 1] Combined metric improved to 0.2797;  reset wait counter
# ------------------------------
# 154/154 - 13s - 82ms/step - behavior_alcohol_loss: 1.3797 - behavior_alcohol_macro_f1: 0.3594 - behavior_drug_loss: 0.9512 - behavior_drug_macro_f1: 0.2947 - behavior_tobacco_loss: 1.5021 - behavior_tobacco_macro_f1: 0.3365 - loss: 6.6573 - sdoh_community_absent_f1: 0.2707 - sdoh_community_absent_loss: 0.3486 - sdoh_community_present_f1: 0.7881 - sdoh_community_present_loss: 0.6581 - sdoh_economics_loss: 0.8943 - sdoh_economics_macro_f1: 0.4542 - sdoh_education_f1: 0.1651 - sdoh_education_loss: 0.1600 - sdoh_environment_loss: 0.7514 - sdoh_environment_macro_f1: 0.4860 - val_behavior_alcohol_loss: 1.2919 - val_behavior_alcohol_macro_f1: 0.2602 - val_behavior_drug_loss: 0.7984 - val_behavior_drug_macro_f1: 0.2277 - val_behavior_tobacco_loss: 1.4035 - val_behavior_tobacco_macro_f1: 0.2352 - val_loss: 6.0048 - val_sdoh_community_absent_f1: 0.0000e+00 - val_sdoh_community_absent_loss: 0.3255 - val_sdoh_community_present_f1: 0.7742 - val_sdoh_community_present_loss: 0.6120 - val_sdoh_economics_loss: 0.7897 - val_sdoh_economics_macro_f1: 0.3277 - val_sdoh_education_f1: 0.0000e+00 - val_sdoh_education_loss: 0.1234 - val_sdoh_environment_loss: 0.6514 - val_sdoh_environment_macro_f1: 0.4127
# Epoch 10/128
# [Epoch 10] Combined metric improved to 0.5982;  reset wait counter
# ------------------------------
# 154/154 - 6s - 39ms/step - behavior_alcohol_loss: 0.4824 - behavior_alcohol_macro_f1: 0.6857 - behavior_drug_loss: 0.2526 - behavior_drug_macro_f1: 0.6012 - behavior_tobacco_loss: 0.5658 - behavior_tobacco_macro_f1: 0.7130 - loss: 2.3581 - sdoh_community_absent_f1: 0.5254 - sdoh_community_absent_loss: 0.2035 - sdoh_community_present_f1: 0.8830 - sdoh_community_present_loss: 0.3265 - sdoh_economics_loss: 0.3226 - sdoh_economics_macro_f1: 0.7848 - sdoh_education_f1: 0.2781 - sdoh_education_loss: 0.0711 - sdoh_environment_loss: 0.1226 - sdoh_environment_macro_f1: 0.6531 - val_behavior_alcohol_loss: 0.6057 - val_behavior_alcohol_macro_f1: 0.6670 - val_behavior_drug_loss: 0.3533 - val_behavior_drug_macro_f1: 0.5363 - val_behavior_tobacco_loss: 0.6882 - val_behavior_tobacco_macro_f1: 0.7070 - val_loss: 3.0581 - val_sdoh_community_absent_f1: 0.4970 - val_sdoh_community_absent_loss: 0.1987 - val_sdoh_community_present_f1: 0.8644 - val_sdoh_community_present_loss: 0.3803 - val_sdoh_economics_loss: 0.4634 - val_sdoh_economics_macro_f1: 0.7333 - val_sdoh_education_f1: 0.1579 - val_sdoh_education_loss: 0.0931 - val_sdoh_environment_loss: 0.2643 - val_sdoh_environment_macro_f1: 0.6227
# Epoch 11/128
# [Epoch 11] Combined metric improved to 0.6091;  reset wait counter
# ------------------------------
# 154/154 - 6s - 39ms/step - behavior_alcohol_loss: 0.4538 - behavior_alcohol_macro_f1: 0.6904 - behavior_drug_loss: 0.2557 - behavior_drug_macro_f1: 0.6070 - behavior_tobacco_loss: 0.5229 - behavior_tobacco_macro_f1: 0.7349 - loss: 2.1872 - sdoh_community_absent_f1: 0.6180 - sdoh_community_absent_loss: 0.1700 - sdoh_community_present_f1: 0.8908 - sdoh_community_present_loss: 0.2993 - sdoh_economics_loss: 0.2945 - sdoh_economics_macro_f1: 0.8009 - sdoh_education_f1: 0.3590 - sdoh_education_loss: 0.0701 - sdoh_environment_loss: 0.1101 - sdoh_environment_macro_f1: 0.6585 - val_behavior_alcohol_loss: 0.6399 - val_behavior_alcohol_macro_f1: 0.6365 - val_behavior_drug_loss: 0.3516 - val_behavior_drug_macro_f1: 0.4954 - val_behavior_tobacco_loss: 0.6832 - val_behavior_tobacco_macro_f1: 0.7014 - val_loss: 3.0362 - val_sdoh_community_absent_f1: 0.6633 - val_sdoh_community_absent_loss: 0.1776 - val_sdoh_community_present_f1: 0.8842 - val_sdoh_community_present_loss: 0.3796 - val_sdoh_economics_loss: 0.4412 - val_sdoh_economics_macro_f1: 0.7710 - val_sdoh_education_f1: 0.1000 - val_sdoh_education_loss: 0.0965 - val_sdoh_environment_loss: 0.2553 - val_sdoh_environment_macro_f1: 0.6208
# Epoch 12/128
# [Epoch 12] Combined metric improved to 0.6381;  reset wait counter
# Epoch 37/128
# [Epoch 37] Combined metric improved to 0.7640;  reset wait counter
# ------------------------------
# ...
# Epoch 60/128
# [Epoch 60] No improvement (current 0.7694, best 0.7897), wait 4/15
# ------------------------------
# 154/154 - 6s - 38ms/step - behavior_alcohol_loss: 0.0782 - behavior_alcohol_macro_f1: 0.9461 - behavior_drug_loss: 0.0793 - behavior_drug_macro_f1: 0.8680 - behavior_tobacco_loss: 0.0916 - behavior_tobacco_macro_f1: 0.9438 - loss: 0.3908 - sdoh_community_absent_f1: 0.9664 - sdoh_community_absent_loss: 0.0200 - sdoh_community_present_f1: 0.9941 - sdoh_community_present_loss: 0.0190 - sdoh_economics_loss: 0.0458 - sdoh_economics_macro_f1: 0.9737 - sdoh_education_f1: 0.8951 - sdoh_education_loss: 0.0148 - sdoh_environment_loss: 0.0260 - sdoh_environment_macro_f1: 0.8956 - val_behavior_alcohol_loss: 0.8227 - val_behavior_alcohol_macro_f1: 0.7792 - val_behavior_drug_loss: 0.5127 - val_behavior_drug_macro_f1: 0.6384 - val_behavior_tobacco_loss: 0.8963 - val_behavior_tobacco_macro_f1: 0.8158 - val_loss: 4.1296 - val_sdoh_community_absent_f1: 0.8472 - val_sdoh_community_absent_loss: 0.2234 - val_sdoh_community_present_f1: 0.9448 - val_sdoh_community_present_loss: 0.4766 - val_sdoh_economics_loss: 0.6610 - val_sdoh_economics_macro_f1: 0.8645 - val_sdoh_education_f1: 0.5517 - val_sdoh_education_loss: 0.1892 - val_sdoh_environment_loss: 0.3317 - val_sdoh_environment_macro_f1: 0.7136
# Epoch 61/128
# [Epoch 61] No improvement (current 0.7665, best 0.7897), wait 5/15
# ------------------------------
# 154/154 - 6s - 38ms/step - behavior_alcohol_loss: 0.0837 - behavior_alcohol_macro_f1: 0.9427 - behavior_drug_loss: 0.0822 - behavior_drug_macro_f1: 0.8678 - behavior_tobacco_loss: 0.0768 - behavior_tobacco_macro_f1: 0.9480 - loss: 0.3728 - sdoh_community_absent_f1: 0.9699 - sdoh_community_absent_loss: 0.0163 - sdoh_community_present_f1: 0.9931 - sdoh_community_present_loss: 0.0258 - sdoh_economics_loss: 0.0353 - sdoh_economics_macro_f1: 0.9817 - sdoh_education_f1: 0.9247 - sdoh_education_loss: 0.0122 - sdoh_environment_loss: 0.0248 - sdoh_environment_macro_f1: 0.9010 - val_behavior_alcohol_loss: 0.8132 - val_behavior_alcohol_macro_f1: 0.7761 - val_behavior_drug_loss: 0.5512 - val_behavior_drug_macro_f1: 0.6414 - val_behavior_tobacco_loss: 0.9275 - val_behavior_tobacco_macro_f1: 0.8139 - val_loss: 4.3662 - val_sdoh_community_absent_f1: 0.8319 - val_sdoh_community_absent_loss: 0.2431 - val_sdoh_community_present_f1: 0.9473 - val_sdoh_community_present_loss: 0.5203 - val_sdoh_economics_loss: 0.7186 - val_sdoh_economics_macro_f1: 0.8675 - val_sdoh_education_f1: 0.5614 - val_sdoh_education_loss: 0.2030 - val_sdoh_environment_loss: 0.3732 - val_sdoh_environment_macro_f1: 0.6928
# Epoch 70/128
# [Epoch 70] No improvement (current 0.7871, best 0.7897), wait 14/15
# ------------------------------
# 154/154 - 6s - 39ms/step - behavior_alcohol_loss: 0.0582 - behavior_alcohol_macro_f1: 0.9682 - behavior_drug_loss: 0.0639 - behavior_drug_macro_f1: 0.8892 - behavior_tobacco_loss: 0.0686 - behavior_tobacco_macro_f1: 0.9633 - loss: 0.3120 - sdoh_community_absent_f1: 0.9845 - sdoh_community_absent_loss: 0.0123 - sdoh_community_present_f1: 0.9960 - sdoh_community_present_loss: 0.0154 - sdoh_economics_loss: 0.0415 - sdoh_economics_macro_f1: 0.9786 - sdoh_education_f1: 0.9268 - sdoh_education_loss: 0.0098 - sdoh_environment_loss: 0.0261 - sdoh_environment_macro_f1: 0.8812 - val_behavior_alcohol_loss: 0.9881 - val_behavior_alcohol_macro_f1: 0.7938 - val_behavior_drug_loss: 0.6255 - val_behavior_drug_macro_f1: 0.6458 - val_behavior_tobacco_loss: 0.9704 - val_behavior_tobacco_macro_f1: 0.8243 - val_loss: 4.7961 - val_sdoh_community_absent_f1: 0.8522 - val_sdoh_community_absent_loss: 0.2490 - val_sdoh_community_present_f1: 0.9454 - val_sdoh_community_present_loss: 0.5938 - val_sdoh_economics_loss: 0.8231 - val_sdoh_economics_macro_f1: 0.8708 - val_sdoh_education_f1: 0.5758 - val_sdoh_education_loss: 0.1830 - val_sdoh_environment_loss: 0.3474 - val_sdoh_environment_macro_f1: 0.7889
# Epoch 71/128
# [Epoch 71] No improvement (current 0.7740, best 0.7897), wait 15/15
# ------------------------------
# Training stopped early as there is no improvement for 15 epochs
#  So END Training.
# 154/154 - 6s - 38ms/step - behavior_alcohol_loss: 0.0735 - behavior_alcohol_macro_f1: 0.9543 - behavior_drug_loss: 0.0589 - behavior_drug_macro_f1: 0.8946 - behavior_tobacco_loss: 0.0704 - behavior_tobacco_macro_f1: 0.9583 - loss: 0.3267 - sdoh_community_absent_f1: 0.9689 - sdoh_community_absent_loss: 0.0210 - sdoh_community_present_f1: 0.9939 - sdoh_community_present_loss: 0.0176 - sdoh_economics_loss: 0.0364 - sdoh_economics_macro_f1: 0.9828 - sdoh_education_f1: 0.9444 - sdoh_education_loss: 0.0086 - sdoh_environment_loss: 0.0238 - sdoh_environment_macro_f1: 0.8985 - val_behavior_alcohol_loss: 0.8378 - val_behavior_alcohol_macro_f1: 0.7825 - val_behavior_drug_loss: 0.5123 - val_behavior_drug_macro_f1: 0.7008 - val_behavior_tobacco_loss: 0.9706 - val_behavior_tobacco_macro_f1: 0.8201 - val_loss: 4.4582 - val_sdoh_community_absent_f1: 0.7860 - val_sdoh_community_absent_loss: 0.2782 - val_sdoh_community_present_f1: 0.9464 - val_sdoh_community_present_loss: 0.5666 - val_sdoh_economics_loss: 0.7602 - val_sdoh_economics_macro_f1: 0.8619 - val_sdoh_education_f1: 0.5672 - val_sdoh_education_loss: 0.1741 - val_sdoh_environment_loss: 0.3424 - val_sdoh_environment_macro_f1: 0.7272

# %% [markdown]
# #### 4.1.6 Test LSTM Performance

# %%
# Smae as above, Convert the training and validation text lists into TensorFlow string tensors
test_texts_tensor = tf.convert_to_tensor(np.array(test_texts).reshape(-1, 1), dtype=tf.string)
# Smae as above, extracts label arrays for eight tasks from training and validation data
test_ylist = [data_test[col].values for col in full_cols]

y_test_preds = model_lstm6.predict(test_texts_tensor)
y_test_pred_labels = [np.argmax(pred, axis=1) for pred in y_test_preds]

precision_macro = []
recall_macro = []
f1_macro = []
accuracy_list = []

precision_weighted = []
recall_weighted = []
f1_weighted = []

for i, label in enumerate(full_cols):
    y_true = test_ylist[i]
    y_pred = y_test_pred_labels[i]

    print(f"\nLabel: {label}")
    print(classification_report(test_ylist[i], y_test_pred_labels[i], digits=4))

    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    acc = accuracy_score(y_true, y_pred)

    precision_macro.append(precision)
    recall_macro.append(recall)
    f1_macro.append(f1)
    accuracy_list.append(acc)

    precision_w = precision_score(y_true, y_pred, average='weighted')
    recall_w = recall_score(y_true, y_pred, average='weighted')
    f1_w = f1_score(y_true, y_pred, average='weighted')

    precision_weighted.append(precision_w)
    recall_weighted.append(recall_w)
    f1_weighted.append(f1_w)

print("\nBiLSTM Macro-Average Results:")
print(f"Macro Precision: {np.mean(precision_macro):.4f}")
print(f"Macro Recall:    {np.mean(recall_macro):.4f}")
print(f"Macro F1-Score:  {np.mean(f1_macro):.4f}")
print(f"Macro Accuracy:  {np.mean(accuracy_list):.4f}")

print("\nBiLSTM Weighted-Average Results:")
print(f"Weighted Precision: {sum(precision_weighted) / len(precision_weighted):.4f}")
print(f"Weighted Recall: {sum(recall_weighted) / len(recall_weighted):.4f}")
print(f"Weighted F1-Score: {sum(f1_weighted) / len(f1_weighted):.4f}")

# Clear Classific Refort
print("\nBiLSTM Detailed Per-Task Evaluation:")
for i, name in enumerate(full_cols):
    print(f"{name:<25} | Acc: {accuracy_list[i]:.4f} | Prec: {precision_macro[i]:.4f} | Rec: {recall_macro[i]:.4f} | F1: {f1_macro[i]:.4f}")
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# Label: sdoh_community_present
#               precision    recall  f1-score   support
#
#            0     0.9266    0.8564    0.8901       383
#            1     0.9213    0.9612    0.9408       670
#
#     accuracy                         0.9231      1053
#    macro avg     0.9239    0.9088    0.9155      1053
# weighted avg     0.9232    0.9231    0.9224      1053
#
#
# Label: sdoh_community_absent
#               precision    recall  f1-score   support
#
#            0     0.9679    0.9668    0.9674       935
#            1     0.7395    0.7458    0.7426       118
#
#     accuracy                         0.9421      1053
#    macro avg     0.8537    0.8563    0.8550      1053
# weighted avg     0.9423    0.9421    0.9422      1053
#
#
# Label: sdoh_education
#               precision    recall  f1-score   support
#
#            0     0.9941    0.9853    0.9897      1022
#            1     0.6250    0.8065    0.7042        31
#
#     accuracy                         0.9801      1053
#    macro avg     0.8095    0.8959    0.8470      1053
# weighted avg     0.9832    0.9801    0.9813      1053
#
#
# Label: sdoh_economics
#               precision    recall  f1-score   support
#
#            0     0.9340    0.9471    0.9405       643
#            1     0.7744    0.6959    0.7331       148
#            2     0.8619    0.8817    0.8717       262
#
#     accuracy                         0.8955      1053
#    macro avg     0.8568    0.8416    0.8484      1053
# weighted avg     0.8937    0.8955    0.8943      1053
#
#
# Label: sdoh_environment
#               precision    recall  f1-score   support
#
#            0     0.9233    0.9847    0.9530       391
#            1     0.9874    0.9571    0.9720       653
#            2     0.6667    0.2222    0.3333         9
#
#     accuracy                         0.9611      1053
#    macro avg     0.8591    0.7213    0.7528      1053
# weighted avg     0.9608    0.9611    0.9595      1053
#
#
# Label: behavior_alcohol
#               precision    recall  f1-score   support
#
#            0     0.9206    0.9355    0.9280       248
#            1     0.8723    0.9003    0.8861       311
#            2     0.6056    0.5584    0.5811        77
#            3     0.9233    0.9183    0.9208       367
#            4     0.6818    0.6000    0.6383        50
#
#     accuracy                         0.8756      1053
#    macro avg     0.8007    0.7825    0.7908      1053
# weighted avg     0.8729    0.8756    0.8740      1053
#
#
# Label: behavior_tobacco
#               precision    recall  f1-score   support
#
#            0     0.9027    0.8653    0.8836       193
#            1     0.7910    0.7020    0.7439       151
#            2     0.8879    0.8962    0.8920       318
#            3     0.8880    0.9615    0.9233       338
#            4     0.7660    0.6792    0.7200        53
#
#     accuracy                         0.8727      1053
#    macro avg     0.8471    0.8209    0.8326      1053
# weighted avg     0.8706    0.8727    0.8706      1053
#
#
# Label: behavior_drug
#               precision    recall  f1-score   support
#
#            0     0.9622    0.9861    0.9740       646
#            1     0.5500    0.3548    0.4314        31
#            2     0.6774    0.6364    0.6562        33
#            3     0.9194    0.9595    0.9390       321
#            4     0.8000    0.1818    0.2963        22
#
#     accuracy                         0.9316      1053
#    macro avg     0.7818    0.6237    0.6594      1053
# weighted avg     0.9247    0.9316    0.9232      1053
#
#
# BiLSTM Macro-Average Results:
# Macro Precision: 0.8416
# Macro Recall:    0.8064
# Macro F1-Score:  0.8127
# Macro Accuracy:  0.9227
#
# BiLSTM Weighted-Average Results:
# Weighted Precision: 0.9214
# Weighted Recall: 0.9227
# Weighted F1-Score: 0.9209
#
# BiLSTM Detailed Per-Task Evaluation:
# sdoh_community_present    | Acc: 0.9231 | Prec: 0.9239 | Rec: 0.9088 | F1: 0.9155
# sdoh_community_absent     | Acc: 0.9421 | Prec: 0.8537 | Rec: 0.8563 | F1: 0.8550
# sdoh_education            | Acc: 0.9801 | Prec: 0.8095 | Rec: 0.8959 | F1: 0.8470
# sdoh_economics            | Acc: 0.8955 | Prec: 0.8568 | Rec: 0.8416 | F1: 0.8484
# sdoh_environment          | Acc: 0.9611 | Prec: 0.8591 | Rec: 0.7213 | F1: 0.7528
# behavior_alcohol          | Acc: 0.8756 | Prec: 0.8007 | Rec: 0.7825 | F1: 0.7908
# behavior_tobacco          | Acc: 0.8727 | Prec: 0.8471 | Rec: 0.8209 | F1: 0.8326
# behavior_drug             | Acc: 0.9316 | Prec: 0.7818 | Rec: 0.6237 | F1: 0.6594
